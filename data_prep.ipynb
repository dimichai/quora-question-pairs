# %% [markdown]
# ## This document is made for data cleaning
# #### and that's just what it'll do

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

stop_words = set(stopwords.words('english'))

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load data
train_df = pd.read_csv('raw_train_data.csv')
train_labels = pd.read_csv('train_labels.csv')

test_df = pd.read_csv('raw_test_data.csv')

# %%
train_df['is_duplicate'] = train_labels['is_duplicate']

# %%
# drop empty items
train_df = train_df.dropna()

# %%
def clean_text(text):
    # To lowercase
    text = text.lower()
    
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    
    # remove stopwords
    text = text.split()
    text = [w for w in text if not w in stop_words]
    text = ' '.join(text)
           
    # stem words
    text = text.split()
    stemmer = PorterStemmer()
    text = [stemmer.stem(word) for word in text]
    
    text = ' '.join(text)
    
    return text

# %%
train_df['question1'] = train_df['question1'].apply(clean_text)
train_df['question2'] = train_df['question2'].apply(clean_text)

test_df['question1'] = test_df['question1'].apply(clean_text)
test_df['question2'] = test_df['question2'].apply(clean_text)

# %%
# Get rid of the empty questions in the train set
train_df = train_df[(train_df.question1 != ' ') & (train_df.question2 != ' ')]
train_df = train_df[(train_df.question1 != '') & (train_df.question2 != '')]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323053 entries, 0 to 323163
# Data columns (total 4 columns):
# id              323053 non-null int64
# question1       323053 non-null object
# question2       323053 non-null object
# is_duplicate    323053 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 12.3+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81126 entries, 0 to 81125
# Data columns (total 3 columns):
# test_id      81126 non-null int64
# question1    81126 non-null object
# question2    81126 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %%
train_df.head()
# Out:
#    id                                          question1  \
# 0   0           step step guid invest share market india
# 1   1                stori kohinoor koh - - noor diamond
# 2   2             increas speed internet connect use vpn
# 3   3                                   mental lone solv
# 4   4  one dissolv water quikli sugar salt methan car...
#
#                                            question2  is_duplicate
# 0                 step step guid invest share market             0
# 1  would happen indian govern stole kohinoor koh ...             0
# 2                     internet speed increas hack dn             0
# 3         find remaind math 23 ^ 24 math divid 24 23             0
# 4                       fish would surviv salt water             0

# %%
test_df.head()
# Out:
#    test_id                                          question1  \
# 0       15  would trump presid mean current intern master ...
# 1       20                                  rocket look white
# 2       21                                 caus someon jealou
# 3       23                                      much 30 kv hp
# 4       34                           best travel websit spain
#
#                                            question2
# 0  trump presid affect student present us plan st...
# 1                         rocket booster paint white
# 2                                avoid jealou someon
# 3                     find convers chart cc horsepow
# 4                                 best travel websit

# %%
train_df.to_csv('cleaned_train_data.csv', index=False)
test_df.to_csv('cleaned_test_data.csv', index=False)
